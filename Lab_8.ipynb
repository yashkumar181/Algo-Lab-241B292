# %% [markdown]
# <a href="https://colab.research.google.com/github/yashkumar181/Algo-Lab-241B292/blob/main/Lab_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Minimum Cost Spanning Tree
# Problem Description:
# A spanning tree of a graph can be defined as a graph with minimal set of edges that connect all vertices. A minimum spanning tree of a graph is a spanning tree of the graph with least weight (where the weight is computed by adding the weights of all the edges in the spanning tree). In general, a graph can have multiple minimum spanning trees. The problem is to find a minimum spanning tree of a graph.

# %% [markdown]
# This implementation uses a dictionary to represent the weighted graph, where the vertices are keys, and the values are dictionaries containing their adjacent vertices and their weights.
#
# Please note that this implementation assumes that the input graph is connected and weighted.
#
# First, let's create a simple graph to demonstrate Prim's algorithm:

# %%
graph = {
    "A": {"B": 10, "C": 15, "D": 20},
    "B": {"A": 10, "C": 12},
    "C": {"A": 15, "B": 12, "D": 18},
    "D": {"A": 20, "C": 18},
}

# %% [markdown]
# Now, let's implement Prim's algorithm:

# %%
def prim_algorithm(graph):
    min_tree = {}
    visited = set()
    min_tree[list(graph.keys())[0]] = []
    min_weight = 0

    while len(visited) < len(graph):
        min_edge = float('inf')
        next_vertex = None
        for vertex in min_tree:
            for adj_vertex, weight in graph[vertex].items():
                if adj_vertex not in visited:
                    if weight < min_edge:
                        min_edge = weight
                        next_vertex = adj_vertex

        min_tree[next_vertex] = []
        visited.add(next_vertex)
        min_weight += min_edge

    return min_tree, min_weight

# %% [markdown]
# Now, let's run the Prim's algorithm on the example graph:
# Keep in mind that this example uses a simple representation of a graph, but for more complex cases, you might want to use a library such as NetworkX to represent and manipulate graphs.

# %%
mst, min_weight = prim_algorithm(graph)
print("Minimum Spanning Tree: ", mst)
print("Minimum Weight: ", min_weight)
# Out:
# Minimum Spanning Tree:  {'A': [], 'B': [], 'C': [], 'D': []}
# Minimum Weight:  50

# %% [markdown]
# Take Differnt example of input graph as discussed in lecture slide and use above code to verify the output

# %%
# your sample input of graph
graph = {
    "A": {"B": 4, "C": 3},
    "B": {"A": 4, "C": 1, "D": 2},
    "C": {"A": 3, "B": 1, "D": 4, "E": 5},
    "D": {"B": 2, "C": 4, "E": 1},
    "E": {"C": 5, "D": 1}
}

# %%
#run prims algorithm for sample input
def prim_algorithm(graph):
    min_tree = {}
    visited = set()
    start_ver = list(graph.keys())[0]
    min_tree[start_ver] = []
    visited.add(start_ver)
    min_weight = 0

    while len(visited) < len(graph):
        min_edge = float('inf')
        next_ver = None
        from_ver = None
        for ver in visited:
            for adj_ver, weight in graph[ver].items():
                if adj_ver not in visited and weight < min_edge:
                    min_edge = weight
                    next_ver = adj_ver
                    from_ver = ver
        if next_ver:
            visited.add(next_ver)
            min_tree.setdefault(from_ver, []).append((next_ver, min_edge))
            min_tree[next_ver] = []
            min_weight += min_edge

    return min_tree, min_weight

mst, min_weight = prim_algorithm(graph)
print("Prim's MST:", mst)
print("Prim's Minimum Weight:", min_weight)
# Out:
# Prim's MST: {'A': [('C', 3)], 'C': [('B', 1)], 'B': [('D', 2)], 'D': [('E', 1)], 'E': []}
# Prim's Minimum Weight: 7

# %% [markdown]
# Use same apporach for Kruskal's algorithm

# %%
# implement Kruskal's algorithm

def kru_algorithm(graph):
    edges = []
    for u in graph:
        for v, w in graph[u].items():
            if (v, u, w) not in edges:
                edges.append((u, v, w))
    edges.sort(key=lambda x: x[2])
    parent = {}
    rank = {}
    def find(node):
        if parent[node] != node:
            parent[node] = find(parent[node])
        return parent[node]

    def union(u, v):
        root_u = find(u)
        root_v = find(v)
        if root_u != root_v:
            if rank[root_u] < rank[root_v]:
                parent[root_u] = root_v
            elif rank[root_u] > rank[root_v]:
                parent[root_v] = root_u
            else:
                parent[root_v] = root_u
                rank[root_u] += 1

    for vertex in graph.keys():
        parent[vertex] = vertex
        rank[vertex] = 0

    mst = []
    min_weight = 0

    for u, v, w in edges:
        if find(u) != find(v):
            union(u, v)
            mst.append((u, v, w))
            min_weight += w

    return mst, min_weight

mst_kru, min_weight_kru = kru_algorithm(graph)
print("kruskal's MST:", mst_kru)
print("kruskal's Minimum Weight:", min_weight_kru)
# Out:
# kruskal's MST: [('B', 'C', 1), ('D', 'E', 1), ('B', 'D', 2), ('A', 'C', 3)]
# kruskal's Minimum Weight: 7
